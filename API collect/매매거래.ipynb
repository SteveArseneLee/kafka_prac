# %% [markdown]
# ### 매매거래에서 사용하는 정보들

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
html = urlopen('http://openapi.seoul.go.kr:8088/52576565426c636c3237564a424748/xml/TvApsizesStatus/1/5/')
bs = BeautifulSoup(html, 'html.parser')
print(bs)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <tvapsizesstatus>
# <list_total_count>2120</list_total_count>
# <result>
# <code>INFO-000</code>
# <message>정상 처리되었습니다</message>
# </result>
# <row>
# <dyyyy>2020</dyyyy>
# <am_dg_code>11740700</am_dg_code>
# <gucode>740</gucode>
# <guname>강동구</guname>
# <dong_nm>둔촌제2동</dong_nm>
# ...
