# %% [markdown]
# ### 유동인구
# https://www.nemoapp.kr/Search?ArticleType=1&PageIndex=0&SWLng=127.09055901182849&SWLat=37.50675775682407&NELng=127.11953113127778&NELat=37.51840900068673&Zoom=17&mode=1&category=1&list=true&articleId=&dataType=

# %%
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.nemoapp.kr/Search?ArticleType=1&PageIndex=0&SWLng=127.09055901182849&SWLat=37.50675775682407&NELng=127.11953113127778&NELat=37.51840900068673&Zoom=17&mode=1&category=1&list=true&articleId=&dataType=')
print(res.content)

soup = BeautifulSoup(res.content, 'html.parser')

title = soup.find('title')
print(title.get_text())
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n    <meta charset="utf-8" />\r\n    <meta name="theme-color" content="#ffffff">\r\n    <meta name="theme-color" content="#ffffff">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">\r\n    <meta name="naver-site-verification" content="b26cf81a6deca45ba4f7bc7f8d7c6cd1b096817d" />\r\n    \r\n    \r\n\r\n<meta name="subject" content="\xec\x83\x81\xea\xb0\x80, \xec\x82\xac\xeb\xac\xb4\xec\x8b\xa4 \xec\xb0\xbd\xec\x97\x85\xed\x95\xa0 \xeb\x95\x8c \xeb\x84\xa4\xeb\xaa\xa8" />\r\n<meta name="title" content="\xec\x83\x81\xea\xb0\x80, \xec\x82\xac\xeb\xac\xb4\xec\x8b\xa4 \xec\xb0\xbd\xec\x97\x85\xed\x95\xa0 \xeb\x95\x8c \xeb\x84\xa4\xeb\xaa\xa8" />\r\n<meta name="keywords" content="\xeb\x84\xa4\xeb\xaa\xa8,\xeb\x84\xa4\xeb\xaa\xa8\xec\x95\xb1,\xec\x8a\xa4\xed\x83\x80\xed\x8a\xb8\xec\x97\x85,\xeb\xb9\x84\xec\xa6\x88\xeb\x8b\x88\xec\x8a\xa4\xec\x84\xbc\xed\x84\xb0,\xec\xbd\x94\xec\
# ...
